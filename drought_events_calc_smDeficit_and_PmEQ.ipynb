# %%
# %who
# Out:
# Interactive namespace is empty.

# %% [markdown]
# ### Converting sm deficit to P-E-Q for drought events identified using the full period of record

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

projdir = '/g/data/w97/ad9701/p_prob_analysis/temp_files/'
out_dir = projdir + 'sm_droughts/'
prefix_PmEQ = 'PmEQ_events_30_40perc'
prefix_sm = 'sm_events_30_40perc'
prefix_events = 'events_30_40perc'

awra_dir = '/g/data/fj8/BoM/AWRA/DATA/SCHEDULED-V6/processed/values/day/'
file_names = 'sm_[1-2]*.nc'

lat_slice = slice(-32, -39)
lon_slice = slice(139, 152)

# select time scales at which we want this drought to break
ts_list = [2, 6, 12]

# get the full sm dataset
ds_temp = xr.open_mfdataset(awra_dir + file_names, chunks = {'lat':400,'lon':400})
# converting the datatypes of SM to match P
lat_new = np.float32(ds_temp['latitude'])
lon_new = np.float32(ds_temp['longitude'])

# get the threshold of sm required to end the drought from the reference percentile file
perc_drought_end = 0.4 #0.3
ds_sm_perc = xr.open_dataset(projdir + 'sm_refPeriod_perc/sm_191101_to_202005_30_40perc.nc') #sm_191101_to_202005_perc.nc')
dayofyear = np.arange(366) + 1
da_sm_perc_end = ds_sm_perc['sm'].sel(quantile = perc_drought_end).assign_coords(dayofyear = dayofyear)

def create_filepath(ds, prefix='filename', root_path="."):
    """
    Generate a filepath when given an xarray dataset or dataarray
    """
    start = ds.time[0].dt.strftime("%Y-%m").data
    end = ds.time[-1].dt.strftime("%Y-%m").data
    filepath = f'{root_path}/{prefix}_{start}_{end}.nc'
    return filepath

def calc_PmEQ_from_delSM(delSM, slope, intercept = 0):
    PmEQ_temp = (delSM - intercept)/slope
    PmEQ = PmEQ_temp.where(PmEQ_temp > 0)
    return(PmEQ)

startyr_list = list(range(1911, 2020, 10))

for styr in startyr_list:
    # get the data indicating drought grids (1 = drought)
    drght_files = prefix_events + '_' + str(styr) + '*.nc'
    ds_sm_drght = xr.open_mfdataset(out_dir + drght_files)
    
    # subset the sm data for the same time period as the events
    enyr = ds_sm_drght['time.year'].values[-1]
    time_slice = slice(str(styr) + '-01-01', str(enyr) + '-12-31')
    ds_sm = ds_temp.rename({'latitude':'lat','longitude':'lon'}).assign_coords(lat = lat_new, lon = lon_new).sel(lat = lat_slice, lon = lon_slice, time = time_slice)
    ds_doy = np.array(ds_sm['time.dayofyear'])   # day of the year in ds, the sm dataset
    # soil moisture data array with 'dayofyear' as the co-ordinate variable
    da_sm = ds_sm['sm'].reset_index('time').rename({'time':'dayofyear', 'time_':'time'}).assign_coords({'dayofyear': ds_doy})

    # the sm required to reach the drought ending threshold
    da_sm_end = da_sm_perc_end.sel(dayofyear = ds_doy)
    da_sm_diff = (da_sm_end - da_sm).reset_index('dayofyear').rename({'dayofyear':'time','dayofyear_':'dayofyear'})

    # get the soil mosisture deficit at only the drought grids
    da_sm_diff_drght = da_sm_diff * ds_sm_drght['sm_drought']
    da_sm_diff_drght_wNan = da_sm_diff_drght.where(da_sm_diff_drght > 0).rename('sm_deficit')

    # get corresponding P-E-Q at various timescales from the sm_diff vs. P-E-Q relationship
    PmEQ_drght_wNan_alltimescale = []
    
    for ts in ts_list:
        # get the regression fit results
        data_path = projdir + 'sm_week' + str(ts) + '/'
        fname_reg = 'sm_PmEQ_lm_noIntercept_results.nc'
        ds_reg = xr.open_dataset(data_path + fname_reg)

        # get the coefficient of P-E-Q
        slope = ds_reg['lm_params'].sel(parameter = "PmEQ")

        # get the PmEQ at different timescales
        da_PmEQ_drght_wNan = calc_PmEQ_from_delSM(da_sm_diff_drght_wNan, slope)
        PmEQ_drght_wNan_alltimescale.append(da_PmEQ_drght_wNan)

        # How different is P-E-Q from SM deficit for both the droughts? - commented as I'll plot this later from the saved files
        # da_diff_PmEQ_sm = da_PmEQ_drght_wNan - da_sm_diff_drght_wNan
        # da_diff_PmEQ_sm.mean('time').plot()
        # plt.savefig(outdir + 'drought' + str(i) + '_PmEQ_minus_delSM_mean_week' + str(ts) + '_noIntercept.png')
        # plt.clf()
    
    da_PmEQ_drght = xr.concat(PmEQ_drght_wNan_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('PminusEQ').chunk({'timescale':len(ts_list)})
        
    out_file_PmEQ = create_filepath(da_PmEQ_drght, prefix = prefix_PmEQ, root_path = out_dir)
    out_file_sm = create_filepath(da_sm_diff_drght_wNan, prefix = prefix_sm, root_path = out_dir)
    
    da_PmEQ_drght.to_netcdf(out_file_PmEQ)
    da_sm_diff_drght_wNan.to_netcdf(out_file_sm)

# %% [markdown]
# #### Calculate SM deficit (17 Mar 2022)

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

projdir = '/g/data/w97/ad9701/p_prob_analysis/processed_data/awra/'
drght_dir = projdir + 'sm_droughts/'
out_dir = projdir + 'sm_droughts/'
prefix_PmEQ = 'PmEQ_events'
prefix_sm = 'sm_events'
prefix_events = 'events'

awra_dir = '/g/data/fj8/BoM/AWRA/DATA/SCHEDULED-V6/processed/values/day/'
file_names = 'sm_[1-2]*.nc'

# select time scales at which we want to calculate the drought breaking probabilities
ts_list = [2, 6, 12]

# get the full sm dataset
ds_temp = xr.open_mfdataset(awra_dir + file_names, chunks = {'lat':400,'lon':400})
# converting the datatypes of SM to match P
lat_new = np.float32(ds_temp['latitude'])
lon_new = np.float32(ds_temp['longitude'])

# get the threshold of sm required to end the drought from the reference percentile file
perc_drought_end = 0.3 #0.5 #0.4 #0.3
ds_sm_perc = xr.open_dataset(projdir + 'sm_refPeriod_perc/sm_191101_to_202005_perc.nc') #sm_191101_to_202005_perc_30_40perc.nc')
dayofyear = np.arange(366) + 1
da_sm_perc_end = ds_sm_perc['sm'].sel(quantile = perc_drought_end).assign_coords(dayofyear = dayofyear)

def create_filepath(ds, prefix='filename', root_path="."):
    """
    Generate a filepath when given an xarray dataset or dataarray
    """
    start = ds.time[0].dt.strftime("%Y-%m").data
    end = ds.time[-1].dt.strftime("%Y-%m").data
    filepath = f'{root_path}/{prefix}_{start}_{end}.nc'
    return filepath

startyr_list = list(range(1911, 2020, 10))
ts_list = [2, 6, 12]

for styr in startyr_list:
    # get the data indicating drought grids (1 = drought)
    drght_files = prefix_events + '_' + str(styr) + '*.nc'
    ds_sm_drght = xr.open_mfdataset(drght_dir + drght_files)
    
    # subset the sm data for the same time period as the events
    enyr = ds_sm_drght['time.year'].values[-1]
    time_slice = slice(str(styr) + '-01-01', str(enyr) + '-12-31')
    ds_sm = ds_temp.rename({'latitude':'lat','longitude':'lon'}).assign_coords(lat = lat_new, lon = lon_new).sel(lat = lat_slice, lon = lon_slice, time = time_slice)
    ds_doy = np.array(ds_sm['time.dayofyear'])   # day of the year in ds, the sm dataset
    # soil moisture data array with 'dayofyear' as the co-ordinate variable
    da_sm = ds_sm['sm'].reset_index('time').rename({'time':'dayofyear', 'time_':'time'}).assign_coords({'dayofyear': ds_doy})
    
    sm_deficit_alltimescale = []
    
    # Now using the time scale under consideration, get the future day & the corresponding drought soil moisture threshold on that day
    for ts in ts_list:
        # time values of the future day. The drought thershold corresponding to this day will be used to calculate the sm deficit.
        da_future_time = (ds_sm['time'] + np.timedelta64((7*ts), 'D'))
        da_future_time = da_future_time.assign_coords({'time': da_future_time.values})
        ds_future_doy = np.array(da_future_time['time.dayofyear'])
        
        # get the sm value for the drought ending based on future doy - assign the data coordinates of the current day so that it can be used to calculate sm_diff
        da_sm_end = da_sm_perc_end.sel(dayofyear = ds_future_doy).assign_coords({'dayofyear': ds_doy})
        da_sm_diff = (da_sm_end - da_sm).reset_index('dayofyear').rename({'dayofyear':'time','dayofyear_':'dayofyear'})

        # the drought grids (drought = 1, no-drought = 0, its a flag)
        da_sm_drght = ds_sm_drght['sm_drought'].where(ds_sm_drght['sm_drought'] > 0)
        
        # get the soil mosisture deficit at only the drought grids
        da_sm_diff_drght = (da_sm_diff * da_sm_drght).rename('sm_deficit')
        # da_sm_diff_drght_wNan = da_sm_diff_drght.where(da_sm_diff_drght > 0).rename('sm_deficit')  # allowing negative sm deficits as well, so commented this
        sm_deficit_alltimescale.append(da_sm_diff_drght)

    da_sm_deficit = xr.concat(sm_deficit_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('sm_deficit').chunk({'timescale':len(ts_list)})
    out_file_sm = create_filepath(da_sm_deficit, prefix = prefix_sm, root_path = out_dir)
    da_sm_deficit.to_netcdf(out_file_sm)

# %% [markdown]
# ### Considering a timescale based future day for calculating the soil mositure deficit
# #### The target sm is the threshold value of the future day instead of the current day
# #### The calculated sm deficit & P-E-Q can ALSO BE NEGATIVE
# #### Update on 3 Dec: Included intercept terms back into the eqn. (this is consistent with how the E & Q terms are calculated in AWRA)
# #### 16 Feb: Checking if limiting the range of delSM to the range of the deficits that exist in the region while regression fitting the relationship makes a difference

# %%
# %who
# Out:
# Interactive namespace is empty.

# %%
! squeue -u ad9701
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#              22467       vdi sys/dash   ad9701  R    1:12:41      1 ood-vn5

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

projdir = '/g/data/w97/ad9701/p_prob_analysis/temp_files/'
drght_dir = projdir + 'sm_droughts/'
out_dir = projdir + 'sm_droughts/deficits_basedOn_futureDay_wIntercep_subsetdelSM/'
prefix_PmEQ = 'PmEQ_events_subdelSM'
prefix_sm = 'sm_events_subdelSM'
prefix_events = 'events'

awra_dir = '/g/data/fj8/BoM/AWRA/DATA/SCHEDULED-V6/processed/values/day/'
file_names = 'sm_[1-2]*.nc'

lat_slice = slice(-32, -39)
lon_slice = slice(139, 152)

# select time scales at which we want to calculate the drought breaking probabilities
ts_list = [2, 6, 12]

# get the full sm dataset
ds_temp = xr.open_mfdataset(awra_dir + file_names, chunks = {'lat':400,'lon':400})
# converting the datatypes of SM to match P
lat_new = np.float32(ds_temp['latitude'])
lon_new = np.float32(ds_temp['longitude'])

# get the threshold of sm required to end the drought from the reference percentile file
perc_drought_end = 0.3 #0.5 #0.4 #0.3
ds_sm_perc = xr.open_dataset(projdir + 'sm_refPeriod_perc/sm_191101_to_202005_perc.nc') #sm_191101_to_202005_perc_30_40perc.nc')
dayofyear = np.arange(366) + 1
da_sm_perc_end = ds_sm_perc['sm'].sel(quantile = perc_drought_end).assign_coords(dayofyear = dayofyear)

def create_filepath(ds, prefix='filename', root_path="."):
    """
    Generate a filepath when given an xarray dataset or dataarray
    """
    start = ds.time[0].dt.strftime("%Y-%m").data
    end = ds.time[-1].dt.strftime("%Y-%m").data
    filepath = f'{root_path}/{prefix}_{start}_{end}.nc'
    return filepath

def calc_PmEQ_from_delSM(delSM, slope, intercept = 0):
    PmEQ_temp = (delSM - intercept)/slope
    PmEQ = PmEQ_temp#.where(PmEQ_temp > 0)  # included negative changes as well, so commented
    return(PmEQ)

startyr_list = list(range(1911, 2020, 10))
ts_list = [2, 6, 12]

for styr in startyr_list:
    # get the data indicating drought grids (1 = drought)
    drght_files = prefix_events + '_' + str(styr) + '*.nc'
    ds_sm_drght = xr.open_mfdataset(drght_dir + drght_files)
    
    # subset the sm data for the same time period as the events
    enyr = ds_sm_drght['time.year'].values[-1]
    time_slice = slice(str(styr) + '-01-01', str(enyr) + '-12-31')
    ds_sm = ds_temp.rename({'latitude':'lat','longitude':'lon'}).assign_coords(lat = lat_new, lon = lon_new).sel(lat = lat_slice, lon = lon_slice, time = time_slice)
    ds_doy = np.array(ds_sm['time.dayofyear'])   # day of the year in ds, the sm dataset
    # soil moisture data array with 'dayofyear' as the co-ordinate variable
    da_sm = ds_sm['sm'].reset_index('time').rename({'time':'dayofyear', 'time_':'time'}).assign_coords({'dayofyear': ds_doy})
    
    sm_deficit_alltimescale = []
    PmEQ_drght_alltimescale = []
    
    # Now using the time scale under consideration, get the future day & the corresponding drought soil moisture threshold on that day
    for ts in ts_list:
        # time values of the future day. The drought thershold corresponding to this day will be used to calculate the sm deficit.
        da_future_time = (ds_sm['time'] + np.timedelta64((7*ts), 'D'))
        da_future_time = da_future_time.assign_coords({'time': da_future_time.values})
        ds_future_doy = np.array(da_future_time['time.dayofyear'])
        
        # get the sm value for the drought ending based on future doy - assign the data coordinates of the current day so that it can be used to calculate sm_diff
        da_sm_end = da_sm_perc_end.sel(dayofyear = ds_future_doy).assign_coords({'dayofyear': ds_doy})
        da_sm_diff = (da_sm_end - da_sm).reset_index('dayofyear').rename({'dayofyear':'time','dayofyear_':'dayofyear'})

        # the drought grids (drought = 1, no-drought = 0, its a flag)
        da_sm_drght = ds_sm_drght['sm_drought'].where(ds_sm_drght['sm_drought'] > 0)
        
        # get the soil mosisture deficit at only the drought grids
        da_sm_diff_drght = (da_sm_diff * da_sm_drght).rename('sm_deficit')
        # da_sm_diff_drght_wNan = da_sm_diff_drght.where(da_sm_diff_drght > 0).rename('sm_deficit')  # allowing negative sm deficits as well, so commented this
        sm_deficit_alltimescale.append(da_sm_diff_drght)

        # get corresponding P-E-Q at various timescales from the sm_diff vs. P-E-Q relationship
        # get the regression fit results
        data_path = projdir + 'sm_week' + str(ts) + '/'
        fname_reg = 'sm_PmEQ_lm_results_wNegChanges_subsetdelSM.nc' #'sm_PmEQ_lm_results_wNegChanges.nc'
        ds_reg = xr.open_dataset(data_path + fname_reg)

        # get the coefficient of P-E-Q
        slope = ds_reg['lm_params'].sel(parameter = "PmEQ")
        intercept = ds_reg['lm_params'].sel(parameter = "Intercept")

        # get the PmEQ at different timescales
        da_PmEQ_drght = calc_PmEQ_from_delSM(da_sm_diff_drght, slope, intercept)
        PmEQ_drght_alltimescale.append(da_PmEQ_drght)

    da_PmEQ_drght = xr.concat(PmEQ_drght_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('PminusEQ').chunk({'timescale':len(ts_list)})
    da_sm_deficit = xr.concat(sm_deficit_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('sm_deficit').chunk({'timescale':len(ts_list)})
    
    out_file_PmEQ = create_filepath(da_PmEQ_drght, prefix = prefix_PmEQ, root_path = out_dir)
    out_file_sm = create_filepath(da_sm_deficit, prefix = prefix_sm, root_path = out_dir)

    da_PmEQ_drght.to_netcdf(out_file_PmEQ)
    da_sm_deficit.to_netcdf(out_file_sm)

# %% [markdown]
# #### Including all days in the calculations to check the validation
# #### So the SM deficit is not a deficit anymore, they are deviations from the 30th percentile

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

projdir = '/g/data/w97/ad9701/p_prob_analysis/temp_files/'
drght_dir = projdir + 'sm_droughts/'
out_dir = projdir + 'sm_droughts/deficits_basedOn_futureDay_wIntercep_alldays/'
prefix_PmEQ = 'PmEQ_events_alldays'
prefix_sm = 'sm_events_alldays'
prefix_events = 'events'

awra_dir = '/g/data/fj8/BoM/AWRA/DATA/SCHEDULED-V6/processed/values/day/'
file_names = 'sm_[1-2]*.nc'

lat_slice = slice(-32, -39)
lon_slice = slice(139, 152)

# select time scales at which we want to calculate the drought breaking probabilities
ts_list = [2, 6, 12]

# get the full sm dataset
ds_temp = xr.open_mfdataset(awra_dir + file_names, chunks = {'lat':400,'lon':400})
# converting the datatypes of SM to match P
lat_new = np.float32(ds_temp['latitude'])
lon_new = np.float32(ds_temp['longitude'])

# get the threshold of sm required to end the drought from the reference percentile file
perc_drought_end = 0.3 #0.5 #0.4 #0.3
ds_sm_perc = xr.open_dataset(projdir + 'sm_refPeriod_perc/sm_191101_to_202005_perc.nc') #sm_191101_to_202005_perc_30_40perc.nc')
dayofyear = np.arange(366) + 1
da_sm_perc_end = ds_sm_perc['sm'].sel(quantile = perc_drought_end).assign_coords(dayofyear = dayofyear)

def create_filepath(ds, prefix='filename', root_path="."):
    """
    Generate a filepath when given an xarray dataset or dataarray
    """
    start = ds.time[0].dt.strftime("%Y-%m").data
    end = ds.time[-1].dt.strftime("%Y-%m").data
    filepath = f'{root_path}/{prefix}_{start}_{end}.nc'
    return filepath

def calc_PmEQ_from_delSM(delSM, slope, intercept = 0):
    PmEQ_temp = (delSM - intercept)/slope
    PmEQ = PmEQ_temp#.where(PmEQ_temp > 0)  # included negative changes as well, so commented
    return(PmEQ)

startyr_list = list(range(1911, 2020, 10))
ts_list = [2, 6, 12]

for styr in startyr_list:
    # get the data indicating drought grids (1 = drought)
    drght_files = prefix_events + '_' + str(styr) + '*.nc'
    ds_sm_drght = xr.open_mfdataset(drght_dir + drght_files)
    
    # subset the sm data for the same time period as the events
    enyr = ds_sm_drght['time.year'].values[-1]
    time_slice = slice(str(styr) + '-01-01', str(enyr) + '-12-31')
    ds_sm = ds_temp.rename({'latitude':'lat','longitude':'lon'}).assign_coords(lat = lat_new, lon = lon_new).sel(lat = lat_slice, lon = lon_slice, time = time_slice)
    ds_doy = np.array(ds_sm['time.dayofyear'])   # day of the year in ds, the sm dataset
    # soil moisture data array with 'dayofyear' as the co-ordinate variable
    da_sm = ds_sm['sm'].reset_index('time').rename({'time':'dayofyear', 'time_':'time'}).assign_coords({'dayofyear': ds_doy})
    
    sm_deficit_alltimescale = []
    PmEQ_drght_alltimescale = []
    
    # Now using the time scale under consideration, get the future day & the corresponding drought soil moisture threshold on that day
    for ts in ts_list:
        # time values of the future day. The drought thershold corresponding to this day will be used to calculate the sm deficit.
        da_future_time = (ds_sm['time'] + np.timedelta64((7*ts), 'D'))
        da_future_time = da_future_time.assign_coords({'time': da_future_time.values})
        ds_future_doy = np.array(da_future_time['time.dayofyear'])
        
        # get the sm value for the drought ending based on future doy - assign the data coordinates of the current day so that it can be used to calculate sm_diff
        da_sm_end = da_sm_perc_end.sel(dayofyear = ds_future_doy).assign_coords({'dayofyear': ds_doy})
        da_sm_diff = (da_sm_end - da_sm).reset_index('dayofyear').rename({'dayofyear':'time','dayofyear_':'dayofyear'})

        # the drought grids (drought = 1, no-drought = 0, its a flag)
        da_sm_drght = ds_sm_drght['sm_drought'].where(ds_sm_drght['sm_drought'] > 0)
        
        # get the soil mosisture deficit at only the drought grids - commenting this, to use deviations on all the days
        # da_sm_diff_drght = (da_sm_diff * da_sm_drght).rename('sm_deficit')
        da_sm_diff_drght = da_sm_diff
        # da_sm_diff_drght_wNan = da_sm_diff_drght.where(da_sm_diff_drght > 0).rename('sm_deficit')  # allowing negative sm deficits as well, so commented this
        sm_deficit_alltimescale.append(da_sm_diff_drght)

        # get corresponding P-E-Q at various timescales from the sm_diff vs. P-E-Q relationship
        # get the regression fit results
        data_path = projdir + 'sm_week' + str(ts) + '/'
        fname_reg = 'sm_PmEQ_lm_results_wNegChanges_subsetdelSM.nc' #'sm_PmEQ_lm_results_wNegChanges.nc'
        ds_reg = xr.open_dataset(data_path + fname_reg)

        # get the coefficient of P-E-Q
        slope = ds_reg['lm_params'].sel(parameter = "PmEQ")
        intercept = ds_reg['lm_params'].sel(parameter = "Intercept")

        # get the PmEQ at different timescales
        da_PmEQ_drght = calc_PmEQ_from_delSM(da_sm_diff_drght, slope, intercept)
        PmEQ_drght_alltimescale.append(da_PmEQ_drght)

    da_PmEQ_drght = xr.concat(PmEQ_drght_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('PminusEQ').chunk({'timescale':len(ts_list)})
    da_sm_deficit = xr.concat(sm_deficit_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('sm_deficit').chunk({'timescale':len(ts_list)})
    
    out_file_PmEQ = create_filepath(da_PmEQ_drght, prefix = prefix_PmEQ, root_path = out_dir)
    out_file_sm = create_filepath(da_sm_deficit, prefix = prefix_sm, root_path = out_dir)

    da_PmEQ_drght.to_netcdf(out_file_PmEQ)
    da_sm_deficit.to_netcdf(out_file_sm)

# %%
import pandas as pd
x_dict = {'dmi':[0.2, 0.4, 0.8, 0.9, 0.3, 0.1, -0.7, -0.3], 'soi':[-10, -9, -6, 9, 6, 4, 3, 5], 'sm':[10, 12, 13, 16, 19, 11, 15, 16]}
x_temp = pd.DataFrame(x_dict)
print(x_temp)
(x_temp-x_temp.mean())/x_temp.std()
# Out:
#    dmi  soi  sm
# 0  0.2  -10  10
# 1  0.4   -9  12
# 2  0.8   -6  13
# 3  0.9    9  16
# 4  0.3    6  19
# 5  0.1    4  11
# 6 -0.7    3  15
# 7 -0.3    5  16
#         dmi       soi        sm
# 0 -0.023570 -1.384810 -1.322876
# 1  0.353553 -1.249707 -0.661438
# 2  1.107801 -0.844396 -0.330719
# 3  1.296362  1.182155  0.661438
# 4  0.164992  0.776845  1.653595
# 5 -0.212132  0.506638 -0.992157
# 6 -1.720627  0.371534  0.330719
# 7 -0.966379  0.641741  0.661438

# %%
x_temp.std()
# Out:
# dmi    0.530330
# soi    7.401737
# sm     3.023716
# dtype: float64

# %%
x_new = {'dmi':[0.3], 'soi':[6], 'sm':[15]}
x_new_temp = pd.DataFrame(x_new)
(x_new_temp-x_temp.mean())/x_temp.std()
# Out:
#         dmi       soi        sm
# 0  0.164992  0.776845  0.330719

# %% [markdown]
# #### Update on Jan 10: Fitted two different regressions to the positive and negative changes in delSM

# %%
# %who
# Out:
# PmEQ_drght_alltimescale	 awra_dir	 calc_PmEQ_from_delSM	 create_filepath	 da_PmEQ_drght	 da_PmEQ_drght_neg	 da_PmEQ_drght_pos	 da_future_time	 da_sm
# da_sm_deficit	 da_sm_diff	 da_sm_diff_drght	 da_sm_drght	 da_sm_end	 da_sm_perc_end	 data_path	 dayofyear	 drght_dir
# drght_files	 ds_doy	 ds_future_doy	 ds_neg	 ds_pos	 ds_sm	 ds_sm_drght	 ds_sm_perc	 ds_temp
# enyr	 file_names	 fname_neg	 fname_pos	 intercept	 lat_new	 lat_slice	 lon_new	 lon_slice
# np	 out_dir	 out_file_PmEQ	 out_file_sm	 pd	 perc_drought_end	 plt	 prefix_PmEQ	 prefix_events
# prefix_sm	 projdir	 slope	 slope_cutoff	 sm_deficit_alltimescale	 startyr_list	 styr	 time_slice	 ts
# ts_list	 xr

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

projdir = '/g/data/w97/ad9701/p_prob_analysis/temp_files/'
drght_dir = projdir + 'sm_droughts/deficits_basedOn_futureDay_wIntercep_10_30perc_2Reg/'
out_dir = projdir + 'sm_droughts/deficits_basedOn_futureDay_wIntercep_10_30perc_2Reg/'
prefix_PmEQ = 'PmEQ_events_10_30perc'
prefix_sm = 'sm_events_10_30perc'
prefix_events = 'events'

awra_dir = '/g/data/fj8/BoM/AWRA/DATA/SCHEDULED-V6/processed/values/day/'
file_names = 'sm_[1-2]*.nc'

lat_slice = slice(-32, -39)
lon_slice = slice(139, 152)

# select time scales at which we want to calculate the drought breaking probabilities
# ts_list = [2] #, 6, 12]

# get the full sm dataset
ds_temp = xr.open_mfdataset(awra_dir + file_names, chunks = {'lat':400,'lon':400})
# converting the datatypes of SM to match P
lat_new = np.float32(ds_temp['latitude'])
lon_new = np.float32(ds_temp['longitude'])

# get the threshold of sm required to end the drought from the reference percentile file
perc_drought_end = 0.3 #0.5 #0.4 #0.3
ds_sm_perc = xr.open_dataset(projdir + 'sm_refPeriod_perc/sm_191101_to_202005_perc.nc') #sm_191101_to_202005_perc_30_40perc.nc')
dayofyear = np.arange(366) + 1
da_sm_perc_end = ds_sm_perc['sm'].sel(quantile = perc_drought_end).assign_coords(dayofyear = dayofyear)

def create_filepath(ds, prefix='filename', root_path="."):
    """
    Generate a filepath when given an xarray dataset or dataarray
    """
    start = ds.time[0].dt.strftime("%Y-%m").data
    end = ds.time[-1].dt.strftime("%Y-%m").data
    filepath = f'{root_path}/{prefix}_{start}_{end}.nc'
    return filepath

def calc_PmEQ_from_delSM(delSM, slope, intercept = 0):
    PmEQ_temp = (delSM - intercept)/slope
    PmEQ = PmEQ_temp#.where(PmEQ_temp > 0)  # included negative changes as well, so commented
    return(PmEQ)

startyr_list = list(range(1911, 2020, 10))
ts_list = [2, 6, 12]

slope_cutoff = 0.05  #otherwise some very small slope values in the regressions for negative delSM causes problems

for styr in startyr_list:
    # get the data indicating drought grids (1 = drought)
    drght_files = prefix_events + '_' + str(styr) + '*.nc'
    ds_sm_drght = xr.open_mfdataset(drght_dir + drght_files)
    
    # subset the sm data for the same time period as the events
    enyr = ds_sm_drght['time.year'].values[-1]
    time_slice = slice(str(styr) + '-01-01', str(enyr) + '-12-31')
    ds_sm = ds_temp.rename({'latitude':'lat','longitude':'lon'}).assign_coords(lat = lat_new, lon = lon_new).sel(lat = lat_slice, lon = lon_slice, time = time_slice)
    ds_doy = np.array(ds_sm['time.dayofyear'])   # day of the year in ds, the sm dataset
    # soil moisture data array with 'dayofyear' as the co-ordinate variable
    da_sm = ds_sm['sm'].reset_index('time').rename({'time':'dayofyear', 'time_':'time'}).assign_coords({'dayofyear': ds_doy})
    
    sm_deficit_alltimescale = []
    PmEQ_drght_alltimescale = []
    
    # Now using the time scale under consideration, get the future day & the corresponding drought soil moisture threshold on that day
    for ts in ts_list:
        # time values of the future day. The drought thershold corresponding to this day will be used to calculate the sm deficit.
        da_future_time = (ds_sm['time'] + np.timedelta64((7*ts), 'D'))
        da_future_time = da_future_time.assign_coords({'time': da_future_time.values})
        ds_future_doy = np.array(da_future_time['time.dayofyear'])
        
        # get the sm value for the drought ending based on future doy - assign the data coordinates of the current day so that it can be used to calculate sm_diff
        da_sm_end = da_sm_perc_end.sel(dayofyear = ds_future_doy).assign_coords({'dayofyear': ds_doy})
        da_sm_diff = (da_sm_end - da_sm).reset_index('dayofyear').rename({'dayofyear':'time','dayofyear_':'dayofyear'})

        # the drought grids (drought = 1, no-drought = 0, its a flag)
        da_sm_drght = ds_sm_drght['sm_drought'].where(ds_sm_drght['sm_drought'] > 0)
        
        # get the soil mosisture deficit at only the drought grids
        da_sm_diff_drght = (da_sm_diff * da_sm_drght).rename('sm_deficit')
        # da_sm_diff_drght_wNan = da_sm_diff_drght.where(da_sm_diff_drght > 0).rename('sm_deficit')  # allowing negative sm deficits as well, so commented this
        sm_deficit_alltimescale.append(da_sm_diff_drght)

        # get corresponding P-E-Q at various timescales from the sm_diff vs. P-E-Q relationship
        # get the regression fit results
        data_path = projdir + 'sm_week' + str(ts) + '/'
        
        fname_neg = 'sm_PmEQ_lm_results_wNegChanges_threshpt3_neg.nc'
        ds_neg = xr.open_dataset(data_path + fname_neg)
        # get the coefficient of P-E-Q
        slope = ds_neg['lm_params'].sel(parameter = "PmEQ")
        slope = slope.where(slope>slope_cutoff)
        intercept = ds_neg['lm_params'].sel(parameter = "Intercept")
        # get the PmEQ at different timescales
        da_PmEQ_drght_neg = calc_PmEQ_from_delSM(da_sm_diff_drght.where(da_sm_diff_drght<0, 0), slope, intercept)
        # da_PmEQ_drght_neg = xr.where(~np.isnan(da_sm_diff_drght), da_PmEQ_drght_neg_temp, 0).rename('total_events')
        
        fname_pos = 'sm_PmEQ_lm_results_wNegChanges_threshpt3_pos.nc'
        ds_pos = xr.open_dataset(data_path + fname_pos)
        # get the coefficient of P-E-Q
        slope = ds_pos['lm_params'].sel(parameter = "PmEQ")
        slope = slope.where(slope>slope_cutoff)
        intercept = ds_pos['lm_params'].sel(parameter = "Intercept")
        # get the PmEQ at different timescales
        da_PmEQ_drght_pos = calc_PmEQ_from_delSM(da_sm_diff_drght.where(da_sm_diff_drght>=0, 0), slope, intercept)
        
        da_PmEQ_drght = (da_PmEQ_drght_neg + da_PmEQ_drght_pos)*da_sm_drght  #combined the thersholds calculated using the +ve and -ve regressions. Only consider points where 
        PmEQ_drght_alltimescale.append(da_PmEQ_drght)

    da_PmEQ_drght = xr.concat(PmEQ_drght_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('PminusEQ').chunk({'timescale':len(ts_list)})
    da_sm_deficit = xr.concat(sm_deficit_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('sm_deficit').chunk({'timescale':len(ts_list)})
    
    out_file_PmEQ = create_filepath(da_PmEQ_drght, prefix = prefix_PmEQ, root_path = out_dir)
    out_file_sm = create_filepath(da_sm_deficit, prefix = prefix_sm, root_path = out_dir)

    da_PmEQ_drght.to_netcdf(out_file_PmEQ)
    da_sm_deficit.to_netcdf(out_file_sm)

# %%
d1 = da_PmEQ_drght.sel(timescale = 2)[210,:,:]
d1.where(d1>0).plot() #.mean('time').plot()

# %%
d2 = da_sm_deficit.sel(timescale = 2)[210,:,:]
d2.where(d2>0).plot()

# %%
clim = da_PmEQ_drght.sel(timescale = 2).mean('time')
#clim.where(clim>200).plot()
clim.plot()

# %%
da_sm_deficit.sel(timescale = 2).mean('time').plot()

# %%
da_sm_deficit.sel(timescale = 2).min('time').plot()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/dask/array/reductions.py:538: RuntimeWarning: All-NaN slice encountered
#   return np.nanmin(x_chunk, axis=axis, keepdims=keepdims)

# %%
ds_neg['lm_params'].sel(parameter = "PmEQ").plot()

# %%
ds_neg['lm_params'].sel(parameter = "PmEQ").where(ds_neg['lm_params'].sel(parameter = "PmEQ")>0.05).plot()

# %%
ds_pos['lm_params'].sel(parameter = "PmEQ").plot()

# %%
ds_neg['lm_params'].sel(parameter = "Intercept").plot()

# %%
da_sm_diff_drght.where(da_sm_diff_drght<0, 0)[210,:,:].plot()

# %%
da_PmEQ_drght_pos[210,:,:].plot()

# %% [markdown]
# #### Update on Dec 20: Fitted the delSM ~ P-E-Q regression by season

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

projdir = '/g/data/w97/ad9701/p_prob_analysis/temp_files/'
drght_dir = projdir + 'sm_droughts/'
out_dir = projdir + 'sm_droughts/deficits_basedOn_futureDay_wIntercep_bySeas/'
prefix_PmEQ = 'PmEQ_events'
prefix_sm = 'sm_events'
prefix_events = 'events'

awra_dir = '/g/data/fj8/BoM/AWRA/DATA/SCHEDULED-V6/processed/values/day/'
file_names = 'sm_[1-2]*.nc'

lat_slice = slice(-32, -39)
lon_slice = slice(139, 152)

# select time scales at which we want to calculate the drought breaking probabilities
ts_list = [2, 6, 12]

# get the full sm dataset
ds_temp = xr.open_mfdataset(awra_dir + file_names, chunks = {'lat':400,'lon':400})
# converting the datatypes of SM to match P
lat_new = np.float32(ds_temp['latitude'])
lon_new = np.float32(ds_temp['longitude'])

# get the threshold of sm required to end the drought from the reference percentile file
perc_drought_end = 0.3 #0.4 #0.3
ds_sm_perc = xr.open_dataset(projdir + 'sm_refPeriod_perc/sm_191101_to_202005_perc.nc') #sm_191101_to_202005_perc_30_40perc.nc')
dayofyear = np.arange(366) + 1
da_sm_perc_end = ds_sm_perc['sm'].sel(quantile = perc_drought_end).assign_coords(dayofyear = dayofyear)

def create_filepath(ds, prefix='filename', root_path="."):
    """
    Generate a filepath when given an xarray dataset or dataarray
    """
    start = ds.time[0].dt.strftime("%Y-%m").data
    end = ds.time[-1].dt.strftime("%Y-%m").data
    filepath = f'{root_path}/{prefix}_{start}_{end}.nc'
    return filepath

def calc_PmEQ_from_delSM(delSM, slope, intercept = 0):
    PmEQ_temp = (delSM - intercept)/slope
    PmEQ = PmEQ_temp#.where(PmEQ_temp > 0)  # included negative changes as well, so commented
    return(PmEQ)

startyr_list = list(range(1911, 2020, 10))
ts_list = [2, 6, 12]

for styr in startyr_list:
    # get the data indicating drought grids (1 = drought)
    drght_files = prefix_events + '_' + str(styr) + '*.nc'
    ds_sm_drght = xr.open_mfdataset(drght_dir + drght_files)
    
    # subset the sm data for the same time period as the events
    enyr = ds_sm_drght['time.year'].values[-1]
    time_slice = slice(str(styr) + '-01-01', str(enyr) + '-12-31')
    ds_sm = ds_temp.rename({'latitude':'lat','longitude':'lon'}).assign_coords(lat = lat_new, lon = lon_new).sel(lat = lat_slice, lon = lon_slice, time = time_slice)
    ds_doy = np.array(ds_sm['time.dayofyear'])   # day of the year in ds, the sm dataset
    # soil moisture data array with 'dayofyear' as the co-ordinate variable
    da_sm = ds_sm['sm'].reset_index('time').rename({'time':'dayofyear', 'time_':'time'}).assign_coords({'dayofyear': ds_doy})
    
    sm_deficit_alltimescale = []
    PmEQ_drght_alltimescale = []
    
    # Now using the time scale under consideration, get the future day & the corresponding drought soil moisture threshold on that day
    for ts in ts_list:
        # time values of the future day. The drought thershold corresponding to this day will be used to calculate the sm deficit.
        da_future_time = (ds_sm['time'] + np.timedelta64((7*ts), 'D'))
        da_future_time = da_future_time.assign_coords({'time': da_future_time.values})
        ds_future_doy = np.array(da_future_time['time.dayofyear'])
        
        # get the sm value for the drought ending based on future doy - assign the data coordinates of the current day so that it can be used to calculate sm_diff
        da_sm_end = da_sm_perc_end.sel(dayofyear = ds_future_doy).assign_coords({'dayofyear': ds_doy})
        da_sm_diff = (da_sm_end - da_sm).reset_index('dayofyear').rename({'dayofyear':'time','dayofyear_':'dayofyear'})

        # the drought grids (drought = 1, no-drought = 0, its a flag)
        da_sm_drght = ds_sm_drght['sm_drought'].where(ds_sm_drght['sm_drought'] > 0)
        
        # get the soil mosisture deficit at only the drought grids
        da_sm_diff_drght = (da_sm_diff * da_sm_drght).rename('sm_deficit')
        # da_sm_diff_drght_wNan = da_sm_diff_drght.where(da_sm_diff_drght > 0).rename('sm_deficit')  # allowing negative sm deficits as well, so commented this
        sm_deficit_alltimescale.append(da_sm_diff_drght)

        # get corresponding P-E-Q at various timescales from the sm_diff vs. P-E-Q relationship
        # get the regression fit results
        data_path = projdir + 'sm_week' + str(ts) + '/'
        fname_reg = 'sm_PmEQ_lm_results_wNegChanges_bySeas.nc'
        ds_reg = xr.open_dataset(data_path + fname_reg)

        # get the coefficient of P-E-Q & intercept by season
        slope = ds_reg['lm_params'].sel(parameter = "PmEQ", season = da_sm_diff_drght['time.season'])
        intercept = ds_reg['lm_params'].sel(parameter = "Intercept", season = da_sm_diff_drght['time.season'])

        # get the PmEQ at different timescales
        da_PmEQ_drght = calc_PmEQ_from_delSM(da_sm_diff_drght, slope, intercept)
        PmEQ_drght_alltimescale.append(da_PmEQ_drght)

    da_PmEQ_drght = xr.concat(PmEQ_drght_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('PminusEQ').chunk({'timescale':len(ts_list)})
    da_sm_deficit = xr.concat(sm_deficit_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('sm_deficit').chunk({'timescale':len(ts_list)})
    
    out_file_PmEQ = create_filepath(da_PmEQ_drght, prefix = prefix_PmEQ, root_path = out_dir)
    out_file_sm = create_filepath(da_sm_deficit, prefix = prefix_sm, root_path = out_dir)

    da_PmEQ_drght.to_netcdf(out_file_PmEQ)
    da_sm_deficit.to_netcdf(out_file_sm)
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.10/lib/python3.9/site-packages/xarray/conventions.py:201: SerializationWarning: variable season has data in the form of a dask array with dtype=object, which means it is being loaded into memory to determine a data type that can be safely stored on disk. To avoid this, coerce this variable to a fixed-size dtype with astype() before saving it.
#   warnings.warn(

# %% [markdown]
# ### Scratch Space

# %%
# getting rid of the 'season' dimension from the above data

import xarray as xr
import numpy as np
import glob

def create_filepath(ds, prefix='filename', root_path="."):
    """
    Generate a filepath when given an xarray dataset or dataarray
    """
    start = ds.time[0].dt.strftime("%Y-%m").data
    end = ds.time[-1].dt.strftime("%Y-%m").data
    filepath = f'{root_path}/{prefix}_{start}_{end}.nc'
    return filepath

projdir = '/g/data/w97/ad9701/p_prob_analysis/temp_files/'
drght_dir = projdir + 'sm_droughts/'
out_dir = projdir + 'sm_droughts/deficits_basedOn_futureDay_wIntercep_bySeas/'
prefix_PmEQ = 'PmEQ_events'
prefix_sm = 'sm_events'
prefix_events = 'events'

startyr_list = list(range(1911, 2020, 10))
ts_list = [2, 6, 12]

for yr in startyr_list:
    print(yr)
    fname = glob.glob(out_dir + prefix_PmEQ + '_' + str(yr)  + '*_xx.nc')
    ds = xr.open_dataset(fname[0])
    ds = ds.drop('season')
    out_file_PmEQ = create_filepath(ds['PminusEQ'], prefix = prefix_PmEQ, root_path = out_dir)
    ds.to_netcdf(out_file_PmEQ)
# Out:
# 1911
# 1921
# 1931
# 1941
# 1951
# 1961
# 1971
# 1981
# 1991
# 2001
# 2011

# %% [markdown]
# ### Converting delta SM to P-E-Q for the Millennium drought and the Recent drought

# %%
import xarray as xr
import numpy as np
import pandas as pd

projdir = '/g/data/w97/ad9701/p_prob_analysis/temp_files/'

awra_dir = '/g/data/fj8/BoM/AWRA/DATA/SCHEDULED-V6/processed/values/day/'
file_names = 'sm_[1-2]*.nc'

# get the sm values corresponding to the drought period
ds_temp = xr.open_mfdataset(awra_dir + file_names, chunks = {'lat':400,'lon':400})
# converting the datatypes of SM to match P
lat_new = np.float32(ds_temp['latitude'])
lon_new = np.float32(ds_temp['longitude'])

# get the amount of sm required to end the drought from the reference percentile file
perc_drought_end = 0.3
ds_sm_perc = xr.open_dataset(projdir + 'sm_refPeriod_perc/sm_191101_to_202005_perc.nc')
dayofyear = np.arange(366) + 1
da_sm_perc_end = ds_sm_perc['sm'].sel(quantile = perc_drought_end).assign_coords(dayofyear = dayofyear)

lat_slice = slice(-32, -39)
lon_slice = slice(139, 152)
time_slice = [slice('2000-01-01', '2010-12-31'), slice('2017-01-01', '2020-05-31')] #slice('1911-01-02','2020-03-29')

sm_diff = []
for ts in time_slice:
    ds_sm = ds_temp.rename({'latitude':'lat','longitude':'lon'}).assign_coords(lat = lat_new, lon = lon_new).sel(lat = lat_slice, lon = lon_slice, time = ts)
    ds_doy = np.array(ds_sm['time.dayofyear'])   # day of the year in ds, the sm dataset
    # soil moisture data array with 'dayofyear' as the co-ordinate variable
    da_sm = ds_sm['sm'].reset_index('time').rename({'time':'dayofyear', 'time_':'time'}).assign_coords({'dayofyear': ds_doy})

    # the sm required to reach the drought ending threshold
    da_sm_end = da_sm_perc_end.sel(dayofyear = ds_doy)
    da_sm_diff = (da_sm_end - da_sm).reset_index('dayofyear').rename({'dayofyear':'time','dayofyear_':'dayofyear'})
    sm_diff.append(da_sm_diff)
    
 # get the data indicating drought grids (1 = drought)
drght_file1 = 'sm_drought_200001_to_201012.nc'
drght_file2 = 'sm_drought_201701_to_202005.nc'

# get the location of grid points in drought
ds_sm_drght1 = xr.open_dataset(projdir + 'sm_refPeriod_perc/' + drght_file1)
da_sm_drght1 = ds_sm_drght1['sm_drought']
ds_sm_drght2 = xr.open_dataset(projdir + 'sm_refPeriod_perc/' + drght_file2)
da_sm_drght2 = ds_sm_drght2['sm_drought']

# get the soil mosisture deficit at only the drought grids
sm_diff_drght = []
sm_diff_drght.append(sm_diff[0]*da_sm_drght1)
sm_diff_drght.append(sm_diff[1]*da_sm_drght2)

sm_diff_drght_wNan = [x.where(x > 0) for x in sm_diff_drght]

# select time scales at which we want this drought to break
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'

def calc_PmEQ_from_delSM(delSM, slope, intercept = 0):
    PmEQ_temp = (delSM - intercept)/slope
    PmEQ = PmEQ_temp.where(PmEQ_temp > 0)
    return(PmEQ)

ts_list = [2, 6, 12]

PmEQ_drght_wNan_alltimescale = []
for ts in ts_list:
    # get the regression relationship between soil moisture and P-E-Q
    data_path = projdir + 'sm_week' + str(ts) + '/'
    fname_reg = 'sm_PmEQ_lm_noIntercept_results.nc'
    ds_reg = xr.open_dataset(data_path + fname_reg)

    # names of data arrays within the file
    params = 'lm_params'
    rsq = 'r-squared'

    # get the intercept, coefficient and r-squared of SM = Intercept + coefficient*(P-E-Q)
    # intercept = ds_reg[params].sel(parameter = "Intercept")
    slope = ds_reg[params].sel(parameter = "PmEQ")
    rsq = ds_reg[rsq]

    # get the PmEQ at different timescales
    PmEQ_drght_wNan = [calc_PmEQ_from_delSM(x, slope) for x in sm_diff_drght_wNan]
    
    # How different is P-E-Q from SM deficit for both the droughts? - commented as I've already plotted this
    # for i in range(2):
    #     diff_PmEQ_sm = PmEQ_drght_wNan[i] - sm_diff_drght_wNan[i]
    #     diff_PmEQ_sm.mean('time').plot()
    #     plt.savefig(outdir + 'drought' + str(i) + '_PmEQ_minus_delSM_mean_week' + str(ts) + '_noIntercept.png')
    #     plt.clf()
    
    PmEQ_drght_wNan_alltimescale.append(PmEQ_drght_wNan)

# %%
drght_name = ['millennium', 'recent']
for i in range(2):
    PmEQ_drghtX = xr.concat([PmEQ_drght_wNan_alltimescale[0][i], PmEQ_drght_wNan_alltimescale[1][i], PmEQ_drght_wNan_alltimescale[2][i]], dim = "timescale").assign_coords({'timescale':ts_list})
    out_file = projdir + 'sm_refPeriod_perc/' + drght_name[i] + 'drght_PmEQ_various_timescales.nc'
    PmEQ_drghtX.to_netcdf(out_file)

# %%
import xarray as xr
import numpy as np
import glob

projdir = '/g/data/w97/ad9701/p_prob_analysis/temp_files/'
drght_dir = projdir + 'sm_droughts/'
out_dir = projdir + 'sm_droughts/deficits_basedOn_futureDay_wIntercep_bySeas/'
prefix_PmEQ = 'PmEQ_events'
prefix_sm = 'sm_events'
prefix_events = 'events'

startyr_list = list(range(1911, 2020, 10))
ts_list = [2, 6, 12]

for yr in [1911]:
    print(yr)
    fname = glob.glob(out_dir + prefix_sm + '_' + str(yr)  + '*.nc')
    ds = xr.open_dataset(fname[0])
# Out:
# 1911

# %%
print(ds['sm_deficit'])
# Out:
# <xarray.DataArray 'sm_deficit' (timescale: 3, time: 3653, lat: 141, lon: 261)>
# [403302159 values with dtype=float64]
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#     quantile   float64 0.3
#   * time       (time) datetime64[ns] 1911-01-01 1911-01-02 ... 1920-12-31
#     dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 359 360 361 362 363 364 365 366
#   * timescale  (timescale) int64 2 6 12

# %%
da = ds['PminusEQ']

# %%
displada
# Out:
# <xarray.DataArray 'PminusEQ' (timescale: 3, time: 3653, lat: 141, lon: 261)>
# [403302159 values with dtype=float64]
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#   * time       (time) datetime64[ns] 1911-01-01 1911-01-02 ... 1920-12-31
#   * timescale  (timescale) int64 2 6 12
# Attributes:
#     coordinates:  quantile dayofyear season

# %%
da_sm_diff_drght['time.season']
# Out:
# <xarray.DataArray 'season' (time: 3653)>
# array(['DJF', 'DJF', 'DJF', ..., 'DJF', 'DJF', 'DJF'], dtype='<U3')
# Coordinates:
#     quantile   float64 0.3
#   * time       (time) datetime64[ns] 1911-01-01 1911-01-02 ... 1920-12-31
#     dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 359 360 361 362 363 364 365 366

# %%
slope_bySeas = slope.sel(season = da_sm_diff_drght['time.season'])
intercept_bySeas = intercept.sel(season = da_sm_diff_drght['time.season'])

# %%
calc_PmEQ_from_delSM(da_sm_diff_drght, slope_bySeas, intercept_bySeas)
# Out:
# <xarray.DataArray (time: 3653, lat: 141, lon: 261)>
# dask.array<truediv, shape=(3653, 141, 261), dtype=float64, chunksize=(366, 141, 261), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#     quantile   float64 0.3
#   * time       (time) datetime64[ns] 1911-01-01 1911-01-02 ... 1920-12-31
#     dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 359 360 361 362 363 364 365 366
#     season     (time) object 'DJF' 'DJF' 'DJF' 'DJF' ... 'DJF' 'DJF' 'DJF' 'DJF'

# %%
sm_deifict_gb = sm_deficit_alltimescale.groupby('time.season')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /local/zv2/ad9701/tmp/ipykernel_558649/113950480.py in <module>
# ----> 1 sm_deifict_gb = sm_deficit_alltimescale.groupby('time.season')
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
slope
# Out:
# <xarray.DataArray 'lm_params' (season: 4, lat: 141, lon: 261)>
# [147204 values with dtype=float64]
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#   * season     (season) object 'DJF' 'JJA' 'MAM' 'SON'
#     parameter  <U4 'PmEQ'

# %%
intercept
# Out:
# <xarray.DataArray 'lm_params' (season: 4, lat: 141, lon: 261)>
# [147204 values with dtype=float64]
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#   * season     (season) object 'DJF' 'JJA' 'MAM' 'SON'
#     parameter  <U9 'Intercept'

# %% [markdown]
# ### Scratch Space

# %%
da_PmEQ_drght = xr.concat(PmEQ_drght_wNan_alltimescale, dim = "timescale").assign_coords({'timescale':ts_list}).rename('PminusEQ').chunk({'timescale':len(ts_list)})
da_PmEQ_drght
# Out:
# <xarray.DataArray 'PminusEQ' (timescale: 3, time: 3653, lat: 141, lon: 261)>
# dask.array<rechunk-merge, shape=(3, 3653, 141, 261), dtype=float64, chunksize=(3, 366, 141, 261), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#     quantile   float64 0.3
#   * time       (time) datetime64[ns] 1911-01-01 1911-01-02 ... 1920-12-31
#     dayofyear  (time) int64 dask.array<chunksize=(3653,), meta=np.ndarray>
#     parameter  <U4 'PmEQ'
#   * timescale  (timescale) int64 2 6 12

# %%
da_sm_diff_drght_wNan
# Out:
# <xarray.DataArray (time: 3653, lat: 141, lon: 261)>
# dask.array<where, shape=(3653, 141, 261), dtype=float64, chunksize=(366, 141, 261), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#     quantile   float64 0.3
#   * time       (time) datetime64[ns] 1911-01-01 1911-01-02 ... 1920-12-31
#     dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 359 360 361 362 363 364 365 366

# %%
intercept.plot()

# %%
slope.plot()

# %%
intercept.where(intercept>0).plot()

# %%
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'
prefix = ['millennium', 'recent']
for j in range(len(ts_list)):
    for i in range(2):
        temp = PmEQ_drght_wNan_alltimescale[j][i].mean('time').plot()
        #temp.where(temp>0).plot()
        plt.savefig(outdir + prefix[i] + '_drought_PmEQ_week' + str(ts_list[j]) + '.png')
        plt.clf()

# %%
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'
prefix = ['millennium', 'recent']
lat_size = -32-(-39)
lon_size = 152-139
aspect = lon_size/lat_size
for i in [1]:
    PmEQ_for_plot = []
    for j in range(len(ts_list)):
        temp = PmEQ_drght_wNan_alltimescale[j][i].mean('time')
        PmEQ_for_plot.append(temp)
    xr_for_plt = xr.concat(PmEQ_for_plot, dim="timescale").assign_coords({'timescale':ts_list})
    xr_for_plt.plot(x = "lon", y = "lat", col = "timescale", col_wrap=3, aspect=aspect, cmap="Reds")
    plt.savefig(outdir + prefix[i] + '_drought_PmEQ_week_alltimescale.png')
    plt.clf()
    
    # for i in range(2):
    #     temp = PmEQ_drght_wNan_alltimescale[j][i].mean('time').plot()
    #     #temp.where(temp>0).plot()
    #     plt.savefig(outdir + prefix[i] + '_drought_PmEQ_week' + str(ts_list[j]) + '.png')
    #     plt.clf()

# %%
sm_diff_drght_wNan_timescale
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /local/zv2/ad9701/tmp/ipykernel_1521031/2980002457.py in <module>
# ----> 1 sm_diff_drght_wNan_timescale
#
# NameError: name 'sm_diff_drght_wNan_timescale' is not defined

# %%
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'
prefix = ['millennium', 'recent']
lat_size = -32-(-39)
lon_size = 152-139
aspect = lon_size/lat_size
for i in range(2):
    temp = sm_diff_drght_wNan[i].mean('time')
    temp.where(temp>0).plot(cmap="Reds", aspect=aspect, size=3)
    plt.savefig(outdir + prefix[i] + '_drought_sm_diff_timemean.png')
    plt.clf()

# %%
diff_PmEQ_sm.mean('time').plot()

# %%
PmEQ_mean = PmEQ_drght_wNan[0].mean('time')
PmEQ_mean.where(PmEQ_mean < 0).plot()

# %%
sm_diff_drght_wNan[0].mean('time').plot()

# %%
P_mean = PmEQ_drght_wNan[0].mean('time')
PmEQ_mean.where(PmEQ_mean < 0).plot()

# %%
sm_diff_drght[0].where(sm_diff_drght[0] > 0)[40,:,:].plot()

# %%
sm_diff_drght[0][40,:,:].plot()

# %%
sm_diff_drght[0]
# Out:
# <xarray.DataArray (time: 4018, lat: 141, lon: 261)>
# dask.array<mul, shape=(4018, 141, 261), dtype=float64, chunksize=(366, 141, 261), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#     quantile   float64 0.3
#   * time       (time) datetime64[ns] 2000-01-01 2000-01-02 ... 2010-12-31
#     dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 358 359 360 361 362 363 364 365

# %%
sm_diff_drght[0][40,:,:].plot(cmap="Reds")

# %%
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'

for yr_sel in [str(x) for x in range(2000, 2010)]:
    # yr_sel2 = '2018'
    d_sel = '15'
    figname = 'millennium_drought_' + yr_sel + '_day' + d_sel + '.png'
    # figname = 'recent_drought_' + yr_sel + '_' + yr_sel2 + '_day' + d_sel + '.png'
    time_sel = [yr_sel + m + d_sel for m in ['-01-', '-02-', '-03-', '-04-', '-05-', '-06-', \
                '-07-', '-08-', '-09-', '-10-', '-11-', '-12-']]
    # time_sel.extend([yr_sel2 + m + d_sel for m in ['-01-', '-02-', '-03-', '-04-']])

    lat_size = -32-(-39)
    lon_size = 152-139
    aspect = lon_size/lat_size
    da_sm_drght1.sel(time = time_sel).plot(x = "lon", y = "lat", col = "time", col_wrap = 4, cmap = "Reds", aspect = aspect, size = 1.75)
    plt.savefig(outdir + figname)

# %%
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'
da_sm_drght1.sum(['lat', 'lon']).rename('Number of SEA grids in drought').plot(size=5, aspect=3)
plt.savefig(outdir + 'millennium_drought_no_of_grids_indrought.png')

# %%
sm_diff_drght[0].sum(['lat', 'lon']).rename('Sum of SM deficit at SEA grids in drought').plot(size=5, aspect=3)
plt.savefig(outdir + 'millennium_drought_sum_sm_diff_grids_indrought.png')

# %%
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'
PmEQ_drght_wNan_alltimescale[0][0].sum(['lat', 'lon']).rename('Sum of SM deficit and P-E-Q at SEA grids in drought').plot(size=5, aspect=3, label = 'P-E-Q (2-weeks)', linewidth=4) #, linewidth=2, label='P-E-Q')
PmEQ_drght_wNan_alltimescale[1][0].sum(['lat', 'lon']).rename('Sum of SM deficit and P-E-Q at SEA grids in drought').plot(label = 'P-E-Q (6-weeks)', linewidth=2)
PmEQ_drght_wNan_alltimescale[2][0].sum(['lat', 'lon']).rename('Sum of SM deficit and P-E-Q at SEA grids in drought').plot(label = 'P-E-Q (12-weeks)', linewidth=2)
sm_diff_drght[0].sum(['lat', 'lon']).rename('Sum of SM deficit and P-E-Q at SEA grids in drought').plot(label = 'SM Deficit', linewidth=2,color="black") #size=5, aspect=3) #, label = 'SM Deficit')
plt.legend()
plt.savefig(outdir + 'millennium_drought_moisture_accum_noI_to_break_drought_diffTs.png')

# %%
PmEQ_drght_wNan_alltimescale
# Out:
# [[<xarray.DataArray (time: 4018, lat: 141, lon: 261)>
#   dask.array<where, shape=(4018, 141, 261), dtype=float64, chunksize=(366, 141, 261), chunktype=numpy.ndarray>
#   Coordinates:
#     * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#     * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#       quantile   float64 0.3
#     * time       (time) datetime64[ns] 2000-01-01 2000-01-02 ... 2010-12-31
#       dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 358 359 360 361 362 363 364 365,
#   <xarray.DataArray (time: 1247, lat: 141, lon: 261)>
#   dask.array<where, shape=(1247, 141, 261), dtype=float64, chunksize=(365, 141, 261), chunktype=numpy.ndarray>
#   Coordinates:
#     * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#     * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#       quantile   float64 0.3
#     * time       (time) datetime64[ns] 2017-01-01 2017-01-02 ... 2020-05-31
#       dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 145 146 147 148 149 150 151 152],
#  [<xarray.DataArray (time: 4018, lat: 141, lon: 261)>
#   dask.array<where, shape=(4018, 141, 261), dtype=float64, chunksize=(366, 141, 261), chunktype=numpy.ndarray>
#   Coordinates:
#     * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#     * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#       quantile   float64 0.3
#     * time       (time) datetime64[ns] 2000-01-01 2000-01-02 ... 2010-12-31
#       dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 358 359 360 361 362 363 364 365,
#   <xarray.DataArray (time: 1247, lat: 141, lon: 261)>
#   dask.array<where, shape=(1247, 141, 261), dtype=float64, chunksize=(365, 141, 261), chunktype=numpy.ndarray>
#   Coordinates:
#     * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#     * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#       quantile   float64 0.3
#     * time       (time) datetime64[ns] 2017-01-01 2017-01-02 ... 2020-05-31
#       dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 145 146 147 148 149 150 151 152],
#  [<xarray.DataArray (time: 4018, lat: 141, lon: 261)>
#   dask.array<where, shape=(4018, 141, 261), dtype=float64, chunksize=(366, 141, 261), chunktype=numpy.ndarray>
#   Coordinates:
#     * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#     * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#       quantile   float64 0.3
#     * time       (time) datetime64[ns] 2000-01-01 2000-01-02 ... 2010-12-31
#       dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 358 359 360 361 362 363 364 365,
#   <xarray.DataArray (time: 1247, lat: 141, lon: 261)>
#   dask.array<where, shape=(1247, 141, 261), dtype=float64, chunksize=(365, 141, 261), chunktype=numpy.ndarray>
#   Coordinates:
#     * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#     * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#       quantile   float64 0.3
#     * time       (time) datetime64[ns] 2017-01-01 2017-01-02 ... 2020-05-31
#       dayofyear  (time) int64 1 2 3 4 5 6 7 8 ... 145 146 147 148 149 150 151 152]]

# %%
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'
PmEQ_drght_wNan_alltimescale[0][1].sum(['lat', 'lon']).rename('Sum of SM deficit and P-E-Q at SEA grids in drought').plot(label = 'P-E-Q (2-weeks)', linewidth=4) #, linewidth=2, label='P-E-Q')
PmEQ_drght_wNan_alltimescale[1][1].sum(['lat', 'lon']).rename('Sum of SM deficit and P-E-Q at SEA grids in drought').plot(label = 'P-E-Q (6-weeks)', linewidth=2)
PmEQ_drght_wNan_alltimescale[2][1].sum(['lat', 'lon']).rename('Sum of SM deficit and P-E-Q at SEA grids in drought').plot(label = 'P-E-Q (12-weeks)', linewidth=2)
sm_diff_drght[1].sum(['lat', 'lon']).rename('Sum of SM deficit and P-E-Q at SEA grids in drought').plot(label = 'SM Deficit', linewidth=2,color="black") #size=5, aspect=3) #, label = 'SM Deficit')
plt.legend()
plt.savefig(outdir + 'recent_drought_moisture_accum_noI_to_break_drought_diffTs.png')

# %%
da_sm_drght2.sum(['lat', 'lon']).rename('Number of SEA grids in drought').plot()
plt.savefig(outdir + 'recent_drought_no_of_grids_indrought.png')

# %%
sm_diff_drght[1].sum(['lat', 'lon']).rename('Sum of SM deficit at SEA grids in drought').plot()
plt.savefig(outdir + 'recent_drought_sum_sm_diff_grids_indrought.png')

# %%
da_sm_drght2.groupby('time.month').mean('time')

# %%
import matplotlib.pyplot as plt
outdir = 'figures/drought_events/'

yr_sel = '2019'
yr_sel2 = '2020'
d_sel = '15'
# figname = 'recent_drought_' + yr_sel + '_day' + d_sel + '.png'
figname = 'recent_drought_' + yr_sel + '_' + yr_sel2 + '_day' + d_sel + '.png'
time_sel = [yr_sel + m + d_sel for m in ['-01-', '-02-', '-03-', '-04-', '-05-', '-06-', \
            '-07-', '-08-', '-09-', '-10-', '-11-', '-12-']]
time_sel.extend([yr_sel2 + m + d_sel for m in ['-01-', '-02-', '-03-', '-04-']])

lat_size = -32-(-39)
lon_size = 152-139
aspect = lon_size/lat_size
da_sm_drght2.sel(time = time_sel).plot(x = "lon", y = "lat", col = "time", col_wrap = 4, cmap = "Reds", aspect = aspect, size = 1.75)
plt.savefig(outdir + figname)

# %%
import cartopy.crs as ccrs

yr_sel = '2019'
yr_sel2 = '2020'
d_sel = '15'
# figname = 'recent_drought_' + yr_sel + '_day' + d_sel + '.png'
figname = 'recent_drought_' + yr_sel + '_' + yr_sel2 + '_day' + d_sel + '.png'
time_sel = [yr_sel + m + d_sel for m in ['-01-', '-02-', '-03-', '-04-', '-05-', '-06-', \
            '-07-', '-08-', '-09-', '-10-', '-11-', '-12-']]
time_sel.extend([yr_sel2 + m + d_sel for m in ['-01-', '-02-', '-03-', '-04-']])

fg = da_sm_drght2.sel(time = time_sel).plot(x = 'lon', y = 'lat', col = 'time', col_wrap =4, cmap = "Reds", \
                                                     subplot_kws={ "projection": ccrs.LambertConformal()}, \
                                                     cbar_kwargs={"orientation": "vertical", "shrink": 0.4, "aspect": 40}, robust=True)
    
[ax.coastlines() for ax in fg.axes.flatten()]
# Out:
# [<cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eeea985b0>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7ef7612ca0>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7ef7612970>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7ef7612a00>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eeebd3730>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eece4cc40>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfd820>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfd8e0>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfd9a0>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfda60>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfdb20>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfdbe0>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfdca0>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfdd60>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfde20>,
#  <cartopy.mpl.feature_artist.FeatureArtist at 0x7f7eecdfdee0>]

# %%
da_sm_drght1
# Out:
# <xarray.DataArray 'sm_drought' (lat: 141, lon: 261, time: 4018)>
# [147866418 values with dtype=int64]
# Coordinates:
#   * lat        (lat) float32 -32.0 -32.05 -32.1 -32.15 ... -38.9 -38.95 -39.0
#   * lon        (lon) float32 139.0 139.1 139.1 139.1 ... 151.9 151.9 151.9 152.0
#   * time       (time) datetime64[ns] 2000-01-01 2000-01-02 ... 2010-12-31
#     dayofyear  (time) int64 ...

# %%
! squeue -u ad9701
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#               8551      main dask-wor   ad9701  R       0:52      1 ood-n6
#               8520       vdi sys/dash   ad9701  R    2:56:19      1 ood-vn27
#               8537       vdi sys/dash   ad9701  R    1:35:59      1 ood-vn27
